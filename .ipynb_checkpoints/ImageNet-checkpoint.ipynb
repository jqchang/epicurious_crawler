# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.applications.vgg16 import preprocess_input
import numpy as np
import pandas as pd

df = pd.read_csv('food_info_cleaned.csv')
X = df.to_numpy()
T = pd.read_csv('tag_vector.csv').to_numpy()
N = X.shape[0]
paths = X[:,0]
Y = X[:,1:] # calories, carbohydrates, protein, fat

with open('tag_list.csv','r') as f:
    tags = f.readlines()
for i,t in enumerate(tags):
    tags[i] = t[0:-1]
tags = np.array(tags)
tag_counts = list(zip(tags,np.sum(T,axis=0)))
for c in tag_counts:
    print(c)
# Out:
# ('Oregano', 88)
# ('Sauce Secrets', 25)
# ('Quick and Healthy', 189)
# ('Smoothie', 30)
# ('Blender', 244)
# ('Drink', 357)
# ('Dairy Free', 2299)
# ('Iced Tea', 7)
# ('Vermouth', 20)
# ('Guacamole', 1)
# ('Israel', 1)
# ('Dried Fruit', 111)
# ('Gourmet', 3093)
# ('turkey', 174)
# ('Monterey Jack', 27)
# ('Salsa', 20)
# ('Self', 12)
# ('Suzanne Goin', 1)
# ('Legume', 49)
# ('Bitters', 18)
# ('Mushroom', 447)
# ('Semolina', 8)
# ('Steam', 91)
# ('Lamb', 205)
# ('Italy', 3)
# ('Cook Like a Diner', 5)
# ('Dessert', 2621)
# ('Pork Rib', 43)
# ('Ireland', 3)
# ('Brisket', 28)
# ('Florida', 8)
# ('Sesame', 119)
# ('Mixer', 432)
# ('Trout', 32)
# ('Horseradish', 73)
# ('Grains', 36)
# ('Brunch', 690)
# ('Whole Wheat', 34)
# ('Mother&#x27;s Day', 184)
# ('Fortified Wine', 15)
# ('Quince', 16)
# ('Chickpea', 106)
# ('Maple Syrup', 114)
# ('Halibut', 46)
# ('Hot Pepper', 223)
# ('Buffalo', 3)
# ('Eau de Vie', 1)
# ('Cranberry', 182)
# ('Kosher', 4602)
# ('Sage', 112)
# ('Louisiana', 5)
# ('Low Carb', 151)
# ('Chill', 417)
# ('Persian New Year', 9)
# ('Hummus', 8)
# ('Poblano', 8)
# ('Spritzer', 4)
# ('Tested &amp; Improved', 3)
# ('Cilantro', 382)
# ('Grapefruit', 70)
# ('Father&#x27;s Day', 275)
# ('Tomato', 1042)
# ('Minnesota', 2)
# ('Marshmallow', 18)
# ('Goose', 6)
# ('Brussels Sprout', 62)
# ('Sake', 16)
# ('Queens', 2)
# ('Broil', 207)
# ('Chestnut', 41)
# ('Stir-Fry', 84)
# ('Soy', 63)
# ('Wisconsin', 1)
# ('Steak', 190)
# ('Cherry', 147)
# ('Lingonberry', 2)
# ('Parsley', 320)
# ('Clove', 75)
# ('Pasadena', 1)
# ('Potluck', 481)
# ('Wild Rice', 12)
# ('Wok', 50)
# ('Wedding', 92)
# ('Asian Pear', 10)
# ('Thyme', 194)
# ('Coriander', 123)
# ('Quiche', 6)
# ('Saffron', 62)
# ('Iced Coffee', 2)
# ('Mango', 111)
# ('Oregon', 12)
# ('Souffl\\xc3\\xa9/Meringue', 9)
# ('Brine', 20)
# ('Margarita', 15)
# ('Memorial Day', 2)
# ('Butternut Squash', 97)
# ('Rhubarb', 63)
# ('Pernod', 7)
# ('Colorado', 8)
# ('Milk/Cream', 1054)
# ('Lunar New Year', 39)
# ('Rutabaga', 16)
# ('Kosher for Passover', 51)
# ('Broccoli', 75)
# ('Dairy', 596)
# ('Poppy', 27)
# ('Egg Nog', 5)
# ('Healdsburg', 6)
# ('White Wine', 237)
# ('Mortar and Pestle', 2)
# ('Sandwich Theory', 11)
# ('Custard', 7)
# ('Cottage Cheese', 7)
# ('Chocolate', 697)
# ('Washington, D.C.', 2)
# ('Epi Loves the Microwave', 1)
# ('Wine', 110)
# ('Pasta Salad', 2)
# ('Squash', 135)
# ('Peanut Butter', 39)
# ('Meat', 220)
# ('Pan-Fry', 120)
# ('Parsnip', 70)
# ('leftovers', 14)
# ('Sour Cream', 182)
# ('Radicchio', 43)
# ('Epi Recipe Club', 1)
# ('Edible Gift', 122)
# ('Okra', 17)
# ('Port', 34)
# ('Cr\\xc3\\xaape', 3)
# ('Green Bean', 148)
# ('Potato', 627)
# ('Molasses', 65)
# ('Couscous', 34)
# ('Tree Nut', 79)
# ('Fennel', 225)
# ('Pasta', 537)
# ('Bon App\\xef\\xbf\\xbd\\xef\\xbf\\xbdtit', 1)
# ('Purim', 8)
# ('Thailand', 1)
# ('Marsala', 15)
# ('Minneapolis', 1)
# ('Holiday 2018', 61)
# ('Sugar Conscious', 1814)
# ('Pomegranate Juice', 20)
# ('China', 1)
# ('Cocktail', 235)
# ('Burrito', 2)
# ('Meatloaf', 5)
# ('Brandy', 66)
# ('Atlanta', 2)
# ('Shellfish', 287)
# ('Cardamom', 62)
# ('Dill', 151)
# ('Blueberry', 106)
# ('Poker/Game Night', 110)
# ('Venison', 3)
# ('Appetizer', 1039)
# ('New Jersey', 8)
# ('Kitchen Olympics', 1)
# ('Sunday Stash', 13)
# ('Octopus', 10)
# ('France', 3)
# ('Celery', 171)
# ('Clam', 81)
# ('Michigan', 8)
# ('Passover', 146)
# ('Chive', 129)
# ('Cantaloupe', 25)
# ('Bourbon', 76)
# ('Cupcake', 15)
# ('Bass', 36)
# ('Raw', 50)
# ('Tapioca', 10)
# ('Game', 13)
# ('Liqueur', 88)
# ('Tequila', 41)
# ('Ros\\xc3\\xa9', 2)
# ('Oatmeal', 17)
# ('Chowder', 2)
# ('Anthony Bourdain', 2)
# ('Low Sugar', 3)
# ('Calvados', 13)
# ('Morocco', 1)
# ('Caviar', 6)
# ('Corn', 236)
# ('Sweden', 1)
# ('Cheesecake', 10)
# ('Ground Beef', 76)
# ('Sukkot', 8)
# ('Spring', 1029)
# ('3-Ingredient Recipes', 59)
# ('Barley', 30)
# ('Campari', 18)
# ('Backyard BBQ', 605)
# ('No Meat, No Problem', 24)
# ('Grand Marnier', 4)
# ('Pine Nut', 110)
# ('Caraway', 23)
# ('Grill/Barbecue', 684)
# ('Gouda', 9)
# ('Delaware', 1)
# ('Pittsburgh', 6)
# ('Epi + USHG', 3)
# ('Pecan', 213)
# ('Engagement Party', 152)
# ('Leek', 135)
# ('Cornmeal', 134)
# ('Ginger', 532)
# ('Portland', 10)
# ('Cambodia', 1)
# ('Cocktail Party', 500)
# ('Beef Tenderloin', 25)
# ('Valentine&#x27;s Day', 196)
# ('Champagne', 39)
# ('Muffin', 13)
# ('Biscuit', 12)
# ('Egypt', 1)
# ('Beef', 468)
# ('Radish', 139)
# ('Honey', 281)
# ('Brownie', 11)
# ('Sparkling Wine', 22)
# ('Condiment', 122)
# ('Dinner Party Gameplan', 1)
# ('Herb', 614)
# ('Passion Fruit', 27)
# ('Cheese', 802)
# ('Christmas', 915)
# ('Peru', 2)
# ('Goat Cheese', 128)
# ('Parade', 7)
# ('Bran', 2)
# ('Mozzarella', 134)
# ('Lemongrass', 49)
# ('Tangerine', 22)
# ('Pancake', 15)
# ('Pineapple', 112)
# ('Scotch', 9)
# ('Nut', 470)
# ('Non-Alcoholic', 75)
# ('Wheat/Gluten-Free', 3687)
# ('Cauliflower', 102)
# ('Arizona', 2)
# ('Jerusalem Artichoke', 9)
# ('Apple Juice', 9)
# ('Lychee', 3)
# ('Utah', 1)
# ('Lunch', 1063)
# ('Smoker', 8)
# ('Ukraine', 3)
# ('Myanmar', 1)
# ('Wasabi', 14)
# ('Currant', 40)
# ('Somalia', 1)
# ('Yuca', 2)
# ('Watermelon', 44)
# ('J\\xc3\\xadcama', 13)
# ('Tailgating', 94)
# ('Flat Bread', 12)
# ('Birthday', 228)
# ('Sardine', 7)
# ('Frittata', 8)
# ('Stuffing/Dressing', 89)
# ('Fourth of July', 273)
# ('Freezer Food', 7)
# ('Walnut', 245)
# ('Omelet', 4)
# ('Vermont', 2)
# ('Tarragon', 112)
# ('Healthy', 1295)
# ('Windsor', 1)
# ('The Chew', 1)
# ('Beef Shank', 11)
# ('Pie', 51)
# ('Salad Dressing', 69)
# ('Chicken', 790)
# ('Chile', 14)
# ('Coffee', 107)
# ('Pescatarian', 4541)
# ('Egg', 1092)
# ('Stew', 85)
# ('Plum', 67)
# ('Peach', 123)
# ('White Chocolate', 14)
# ('Tamarind', 18)
# ('Graduation', 94)
# ('Chartreuse', 1)
# ('Raspberry', 146)
# ('Macadamia Nut', 15)
# ('Brooklyn', 4)
# ('Sourdough', 4)
# ('Onion', 942)
# ('Brown Rice', 12)
# ('Mustard Greens', 24)
# ('Drinks', 36)
# ('Artichoke', 85)
# ('Kirsch', 8)
# ('Oyster', 32)
# ('Greece', 1)
# ('Sandwich', 241)
# ('Feta', 136)
# ('Quail', 3)
# ('Arugula', 151)
# ('Turkey', 3)
# ('Spirit', 44)
# ('Digestif', 1)
# ('Pizza', 19)
# ('Tofu', 58)
# ('Mandoline', 5)
# ('Cashew', 59)
# ('Cinco de Mayo', 116)
# ('Phyllo/Puff Pastry Dough', 111)
# ('Laos', 2)
# ('Fry', 302)
# ('Cranberry Sauce', 10)
# ('Basil', 285)
# ('Tuna', 47)
# ('Cumin', 104)
# ('Marinade', 2)
# ('Kiwi', 15)
# ('No Sugar Added', 2128)
# ('Super Bowl', 200)
# ('Fruit Juice', 99)
# ('Persimmon', 24)
# ('Peanut', 119)
# ('Curry', 139)
# ('Cinnamon', 298)
# ('Cookies', 358)
# ('Poultry Sausage', 4)
# ('Sheet-Pan Dinner', 22)
# ('Root Vegetable', 140)
# ('Kid-Friendly', 1954)
# ('Shrimp', 290)
# ('Seed', 123)
# ('Squid', 39)
# ('Alabama', 1)
# ('Ice Cream', 28)
# ('Fish', 447)
# ('Collard Greens', 35)
# ('Organic', 9)
# ('California', 28)
# ('Quick &amp; Easy', 2750)
# ('Duck', 71)
# ('Anchovy', 54)
# ('Cream Cheese', 199)
# ('Bacon', 359)
# ('Lebanon', 2)
# ('Food Processor', 402)
# ('Condiment/Spread', 282)
# ('Zucchini', 152)
# ('Frangelico', 6)
# ('Banana', 92)
# ('Spain', 3)
# ('Georgia', 5)
# ('Rye', 17)
# ('Bastille Day', 24)
# ('Sauce', 300)
# ('Connecticut', 4)
# ('HarperCollins', 362)
# ('Pea', 140)
# ('Party', 657)
# ('Pennsylvania', 12)
# ('Tart', 24)
# ('Dark Chocolate', 19)
# ('Truffle Oil', 3)
# ('cookbooks', 10)
# ('Diwali', 8)
# ('Low Fat', 310)
# ('Double Boiler', 22)
# ('Macaroni and Cheese', 8)
# ('Simmer', 385)
# ('snack week', 33)
# ('Low Cal', 509)
# ('Singapore', 2)
# ('South Carolina', 8)
# ('Almond', 388)
# ('Friendsgiving', 9)
# ('Grenadine', 1)
# ('Whiskey', 45)
# ('Paprika', 69)
# ('Poach', 89)
# ('Marzipan', 1)
# ('Frankenrecipe', 13)
# ('One-Pot Meal', 47)
# ('Candy Thermometer', 43)
# ('Jalape\\xc3\\xb1o', 145)
# ('Kumquat', 25)
# ('Cr\\xc3\\xa9me de Menthe', 2)
# ('Instant Pot', 26)
# ('Fat Free', 220)
# ('St. Patrick&#x27;s Day', 53)
# ('Eggplant', 130)
# ('Tropical Fruit', 38)
# ('Turnip', 62)
# ('#CAKEWEEK', 6)
# ('Seafood', 331)
# ('Cobbler/Crumble', 13)
# ('Pressure Cooker', 19)
# ('Side', 1910)
# ('Chili', 13)
# ('Lobster', 56)
# ('Grill', 410)
# ('Pastry', 112)
# ('Winter', 1542)
# ('Bok Choy', 28)
# ('#cook90', 15)
# ('Yogurt', 288)
# ('#WasteLess', 3)
# ('Ham', 123)
# ('Pork', 579)
# ('Haiti', 3)
# ('Fritter', 3)
# ('Deep-Fry', 90)
# ('Cod', 48)
# ('Pork Tenderloin', 58)
# ('Hors D&#x27;Oeuvre', 62)
# ('Air Fryer', 3)
# ('30 Days of Groceries', 13)
# ('Skewer', 14)
# ('Bell Pepper', 255)
# ('Summer', 2286)
# ('Blackberry', 78)
# ('Juicer', 3)
# ('Labor Day', 11)
# ('Mustard', 237)
# ('Chile Pepper', 296)
# ('Amaretto', 15)
# ('Waffle', 8)
# ('Vinegar', 332)
# ('Kidney Friendly', 1885)
# ('Low Sodium', 78)
# ('Marscarpone', 4)
# ('Orange Juice', 45)
# ('Low/No Sugar', 91)
# ('Diabetes-Friendly', 93)
# ('Houston', 3)
# ('Freeze/Chill', 237)
# ('Washington', 3)
# ('Punch', 26)
# ('Avocado', 172)
# ('Fall', 1593)
# ('Casserole/Gratin', 111)
# ('Raisin', 153)
# ('Tortillas', 112)
# ('Jam or Jelly', 98)
# ('San Francisco', 8)
# ('Tree Nut Free', 5390)
# ('Tea', 63)
# ('Oscars', 104)
# ('Alcoholic', 226)
# ('Malaysia', 1)
# ('Entertaining', 50)
# ('Cheddar', 145)
# ('Tilapia', 6)
# ('Aspen', 1)
# ('Mint', 311)
# ('Illinois', 4)
# ('Bake', 2753)
# ('Boston', 2)
# ('Flaming Hot Summer', 13)
# ('Vanilla', 189)
# ('Vegetable', 856)
# ('Pickles', 40)
# ('Tomatillo', 45)
# ('Epic Hacks', 1)

# %%
path_df = pd.DataFrame(paths)
model = VGG16(weights='imagenet', include_top=False, input_shape=(620,413,3))
datagen = ImageDataGenerator()
img_generator = datagen.flow_from_dataframe(dataframe=path_df, directory='.',
                                            x_col=0, target_size=(620,413))
# features = model.predict_generator(img_generator, verbose=1)

# #     imgnet_features[i] = np.array(f[0])

# print(features.shape)
# print(features.ravel().shape)
# Out:
# -------------------------------------------------------------------
# KeyError                          Traceback (most recent call last)
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2656             try:
# -> 2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'filename'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                          Traceback (most recent call last)
# <ipython-input-79-0d9012e03046> in <module>()
#       2 model = VGG16(weights='imagenet', include_top=False, input_shape=(620,413,3))
#       3 datagen = ImageDataGenerator()
# ----> 4 img_generator = datagen.flow_from_dataframe(dataframe=path_df, directory='.',target_size=(620,413))
#       5 # features = model.predict_generator(img_generator, verbose=1)
#       6
#
# /anaconda3/lib/python3.6/site-packages/keras_preprocessing/image/image_data_generator.py in flow_from_dataframe(self, dataframe, directory, x_col, y_col, weight_col, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, save_to_dir, save_prefix, save_format, subset, interpolation, validate_filenames, **kwargs)
#     681             subset=subset,
#     682             interpolation=interpolation,
# --> 683             validate_filenames=validate_filenames
#     684         )
#     685
#
# /anaconda3/lib/python3.6/site-packages/keras_preprocessing/image/dataframe_iterator.py in __init__(self, dataframe, directory, image_data_generator, x_col, y_col, weight_col, target_size, color_mode, classes, class_mode, batch_size, shuffle, seed, data_format, save_to_dir, save_prefix, save_format, subset, interpolation, dtype, validate_filenames)
#     127         self.dtype = dtype
#     128         # check that inputs match the required class_mode
# --> 129         self._check_params(df, x_col, y_col, weight_col, classes)
#     130         if validate_filenames:  # check which image files are valid and keep them
#     131             df = self._filter_valid_filepaths(df, x_col)
#
# /anaconda3/lib/python3.6/site-packages/keras_preprocessing/image/dataframe_iterator.py in _check_params(self, df, x_col, y_col, weight_col, classes)
#     179             )
#     180         # check that filenames/filepaths column values are all strings
# --> 181         if not all(df[x_col].apply(lambda x: isinstance(x, str))):
#     182             raise TypeError('All values in column x_col={} must be strings.'
#     183                             .format(x_col))
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    2925             if self.columns.nlevels > 1:
#    2926                 return self._getitem_multilevel(key)
# -> 2927             indexer = self.columns.get_loc(key)
#    2928             if is_integer(indexer):
#    2929                 indexer = [indexer]
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2657                 return self._engine.get_loc(key)
#    2658             except KeyError:
# -> 2659                 return self._engine.get_loc(self._maybe_cast_indexer(key))
#    2660         indexer = self.get_indexer([key], method=method, tolerance=tolerance)
#    2661         if indexer.ndim > 1 or indexer.size > 1:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'filename'

# %%
print(X.shape)
# Out:
# (13090, 5)
